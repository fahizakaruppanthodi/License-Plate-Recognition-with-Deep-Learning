# %% [markdown]
# <a href="https://colab.research.google.com/github/fahizakaruppanthodi/License-Plate-Recognition-with-Deep-Learning/blob/main/License_Plate_Recognition_with_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow opencv-python matplotlib imutils

# %%
# Install required libraries
# !pip install easyocr opencv-python-headless matplotlib

# Import libraries
import cv2
import easyocr
import matplotlib.pyplot as plt

# Load image (upload your car image with plate)
from google.colab import files
uploaded = files.upload()

# Replace with your uploaded image filename
image_path = list(uploaded.keys())[0]
img = cv2.imread(image_path)

# Initialize EasyOCR reader
reader = easyocr.Reader(['en'])

# Detect text (license plate text included)
results = reader.readtext(img)

# Draw bounding boxes around detected text
for (bbox, text, prob) in results:
    (top_left, top_right, bottom_right, bottom_left) = bbox
    top_left = tuple(map(int, top_left))
    bottom_right = tuple(map(int, bottom_right))
    cv2.rectangle(img, top_left, bottom_right, (0,255,0), 2)
    cv2.putText(img, text, top_left, cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,0,0), 2)
    print(f"Detected: {text} (Confidence: {prob:.2f})")

# Show final image
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
# ...
#      <input type="file" id="files-47a2b09c-a1c8-4cc3-a011-aa6a6b8b7029" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-47a2b09c-a1c8-4cc3-a011-aa6a6b8b7029">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
